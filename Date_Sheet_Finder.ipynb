# %%
import pandas as pd
# from operator import itemgetter

# %%
df = pd.read_excel("Date_Sheet_Final_Term_Theory_Exams_FALL_2021_Final_Version.xls", skiprows=2)
# df = pd.read_csv("Date_Sheet_Final_Term_Theory_Exams_FALL_2021_Final_Version.csv")
df.head()
# Out:
#                 Date       Time                                   A - 1 (40)  \
# 0  Monday 03-01-2022  0900-1200                                          NaN
# 1                NaN        NaN                                          NaN
# 2                NaN        NaN                                          NaN
# 3                NaN  0100-0400                            FA19-BSI-FA20-BSI
# 4                NaN        NaN  Biotechnology-Linux for Biological Sciences
#
#                                           A - 2 (40)        A - 3 (42)  \
# 0                                  FA21-BSI-SP21-BSI               NaN
# 1  Introduction to Computing-Introduction to Comp...               NaN
# 2                                Mr Munawar ul Zaman               NaN
# 3                                           FA18-FSN          FA20-BEE
# 4                      Fundamentals of Biotechnology  Entrepreneurship
#
#                    A - 1.1 (42)               A - 1.2 (42)  \
# 0                      SP19-BSI                   FA21-FSN
# 1  Modern Programming Languages  Introduction to Computing
# 2                Mr Usman Nasim              Mr Amir Sabri
# 3                           NaN                 FA19-FSN-A
# 4                           NaN   Food Process Engineering
#
#                 A - 1.3 (42)                 A -  2.1 (42)  \
# 0                   FA21-FSN                    FA18-BME-A
# 1  Introduction to Computing  Advanced Material Processing
# 2           Dr M Wasim Sajid              Dr Tuoqeer Anwar
# 3                 FA19-FSN-B                    SP19-FSN-A
# 4   Food Process Engineering                    Metabolism
#
#                    A - 2.2 (42)  ... B 4 (20) B 5 (20) B 6 (20)  \
# 0                    FA18-BME-B  ...      NaN      NaN      NaN
# 1  Advanced Material Processing  ...      NaN      NaN      NaN
# 2               Mr Hassan Iqbal  ...      NaN      NaN      NaN
# 3                    SP19-FSN-B  ...      NaN      NaN      NaN
# 4                    Metabolism  ...      NaN      NaN      NaN
#
#                    B 7 (42)            B 8 (20) B 9 (20) B 10 (20)  \
# 0         SP21-BBA-FA17-BBA            SP18-BBA      NaN       NaN
# 1    Macro Economics-Cinese  Project Management      NaN       NaN
# 2       Ms Sonia Abbas Khan      Mr Bilal lodhi      NaN       NaN
# 3                  FA21-BBA                 NaN      NaN       NaN
# 4  Introduction to Business                 NaN      NaN       NaN
#
#                    B 11 (20)                          B 12 (42)  \
# 0                        NaN                  FA20-BAF-FA21-MB4
# 1                        NaN  Organizational Behavior-O B and L
# 2                        NaN          Mr Muhammad Shoaib Sajjad
# 3          FA18-BAF-SP18-BAF                         FA20-BBA-A
# 4  Introduction to Sociology          Introduction to Sociology
#
#                    B 13 (42)
# 0                   SP19-BBA
# 1    Organizational Behavior
# 2  Mr Syed Ali Ashiq Kirmani
# 3                 FA20-BBA-B
# 4  Introduction to Sociology
#
# [5 rows x 45 columns]

# %%
df.dropna(axis=1, how='all', inplace=True)
df[['Date','Time']] = df[['Date','Time']].fillna(method='ffill')
df.fillna('', inplace=True)
df.drop(columns=['Date.1', 'Time.1', 'Date.2', 'Time.2'], inplace=True)
df.head()
# Out:
#                 Date       Time                                   A - 1 (40)  \
# 0  Monday 03-01-2022  0900-1200
# 1  Monday 03-01-2022  0900-1200
# 2  Monday 03-01-2022  0900-1200
# 3  Monday 03-01-2022  0100-0400                            FA19-BSI-FA20-BSI
# 4  Monday 03-01-2022  0100-0400  Biotechnology-Linux for Biological Sciences
#
#                                           A - 2 (40)        A - 3 (42)  \
# 0                                  FA21-BSI-SP21-BSI
# 1  Introduction to Computing-Introduction to Comp...
# 2                                Mr Munawar ul Zaman
# 3                                           FA18-FSN          FA20-BEE
# 4                      Fundamentals of Biotechnology  Entrepreneurship
#
#                    A - 1.1 (42)               A - 1.2 (42)  \
# 0                      SP19-BSI                   FA21-FSN
# 1  Modern Programming Languages  Introduction to Computing
# 2                Mr Usman Nasim              Mr Amir Sabri
# 3                                               FA19-FSN-A
# 4                                 Food Process Engineering
#
#                 A - 1.3 (42)                 A -  2.1 (42)  \
# 0                   FA21-FSN                    FA18-BME-A
# 1  Introduction to Computing  Advanced Material Processing
# 2           Dr M Wasim Sajid              Dr Tuoqeer Anwar
# 3                 FA19-FSN-B                    SP19-FSN-A
# 4   Food Process Engineering                    Metabolism
#
#                    A - 2.2 (42)  ... B 4 (20) B 5 (20) B 6 (20)  \
# 0                    FA18-BME-B  ...
# 1  Advanced Material Processing  ...
# 2               Mr Hassan Iqbal  ...
# 3                    SP19-FSN-B  ...
# 4                    Metabolism  ...
#
#                    B 7 (42)            B 8 (20) B 9 (20) B 10 (20)  \
# 0         SP21-BBA-FA17-BBA            SP18-BBA
# 1    Macro Economics-Cinese  Project Management
# 2       Ms Sonia Abbas Khan      Mr Bilal lodhi
# 3                  FA21-BBA
# 4  Introduction to Business
#
#                    B 11 (20)                          B 12 (42)  \
# 0                                             FA20-BAF-FA21-MB4
# 1                             Organizational Behavior-O B and L
# 2                                     Mr Muhammad Shoaib Sajjad
# 3          FA18-BAF-SP18-BAF                         FA20-BBA-A
# 4  Introduction to Sociology          Introduction to Sociology
#
#                    B 13 (42)
# 0                   SP19-BBA
# 1    Organizational Behavior
# 2  Mr Syed Ali Ashiq Kirmani
# 3                 FA20-BBA-B
# 4  Introduction to Sociology
#
# [5 rows x 41 columns]

# %%
class_section = input("Enter Your Class and Section").upper()
# Out:
# Enter Your Class and Section fa18-bse-a

# %%
col_list = list(df.columns)

s = ''

for col in col_list:
    if col != 'Date' or col != 'Time':
        s += df[col]

new_df = df[s.str.contains(class_section)]
new_df_list = new_df.to_dict(orient='records')

def get_room(cls_sec, my_dict):
    for key, value in my_dict.items():
         if cls_sec == value:
            return key
    return f"Check Your Date Sheet"

big_list = []

for rec in new_df_list:
    temp_dict = {}
    temp_dict['Date'] = rec['Date']
    temp_dict['Time'] = rec['Time']
    temp_dict['Room'] = get_room(class_section, rec)

    big_list.append(temp_dict)
    
final_df = pd.DataFrame(big_list)
final_df
# Out:
#                    Date       Time        Room
# 0    Tuesday 04-01-2022  0100-0400  C 2.4 (49)
# 1     Friday 07-01-2022  0900-1200    C 1 (49)
# 2     Monday 10-01-2022  0100-0400    C 4 (49)
# 3  Wednesday 12-01-2022  0900-1200  C 2.4 (49)
